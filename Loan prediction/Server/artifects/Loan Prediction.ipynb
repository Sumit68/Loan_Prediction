# %%
import pandas as pd
import numpy as np

# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10,6)

# %%
df = pd.read_csv("Loan Prediction.csv")

# %%
df.shape
# Out:
# (614, 13)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
df['LoanAmount'] = df['LoanAmount'].fillna(146)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(360)

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Credit_History'] = df['Credit_History'].fillna(1.0)

# %%
df.dropna()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.ApplicantIncome,df.LoanAmount)

# %%
pd.crosstab(df.Self_Employed,df.Loan_Status).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Self_Employed'>

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.397394        342.410423
# std        6109.041673        2926.248369   84.037503         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
import seaborn as sns

# %%
sns.displot(df.ApplicantIncome)

# %%
sns.displot(df['CoapplicantIncome'])

# %%
df['total_Income'] = df['ApplicantIncome']+df['CoapplicantIncome']

# %%
plt.hist(df.total_Income, bins=20, rwidth=0.8)
# Out:
# (array([309., 204.,  54.,  23.,   9.,   5.,   1.,   0.,   2.,   2.,   2.,
#           0.,   1.,   0.,   0.,   1.,   0.,   0.,   0.,   1.]),
#  array([ 1442. ,  5419.9,  9397.8, 13375.7, 17353.6, 21331.5, 25309.4,
#         29287.3, 33265.2, 37243.1, 41221. , 45198.9, 49176.8, 53154.7,
#         57132.6, 61110.5, 65088.4, 69066.3, 73044.2, 77022.1, 81000. ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df.total_Income, bins=20, rwidth=0.8)
# Out:
# (array([309., 204.,  54.,  23.,   9.,   5.,   1.,   0.,   2.,   2.,   2.,
#           0.,   1.,   0.,   0.,   1.,   0.,   0.,   0.,   1.]),
#  array([ 1442. ,  5419.9,  9397.8, 13375.7, 17353.6, 21331.5, 25309.4,
#         29287.3, 33265.2, 37243.1, 41221. , 45198.9, 49176.8, 53154.7,
#         57132.6, 61110.5, 65088.4, 69066.3, 73044.2, 77022.1, 81000. ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df.LoanAmount, bins=20, rwidth=0.8)
# Out:
# (array([ 12.,  60., 142., 190.,  90.,  53.,  15.,  18.,  10.,   5.,   4.,
#           2.,   1.,   4.,   3.,   0.,   1.,   2.,   1.,   1.]),
#  array([  9.  ,  43.55,  78.1 , 112.65, 147.2 , 181.75, 216.3 , 250.85,
#         285.4 , 319.95, 354.5 , 389.05, 423.6 , 458.15, 492.7 , 527.25,
#         561.8 , 596.35, 630.9 , 665.45, 700.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.displot(df['total_Income'], kde=True)

# %%
sns.displot(df['LoanAmount'], kde=True)

# %%
df['LoanAmount'].mean()
# Out:
# 146.3973941368078

# %%
sns.boxplot(y=df['LoanAmount'])
# Out:
# <AxesSubplot:ylabel='LoanAmount'>

# %%
sns.boxplot(y=df['total_Income'])
# Out:
# <AxesSubplot:ylabel='total_Income'>

# %%
df['IncomeLog'] = np.log(df['total_Income'])
df['LoanAmountLog'] = np.log(df['LoanAmount'])

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.displot(df['IncomeLog'], kde=True)

# %%
sns.displot(df['LoanAmountLog'], kde=True)

# %%
sns.boxplot(y=df['LoanAmountLog'])
# Out:
# <AxesSubplot:ylabel='LoanAmountLog'>

# %%
sns.boxplot(y=df['IncomeLog'])
# Out:
# <AxesSubplot:ylabel='IncomeLog'>

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.397394        342.410423
# std        6109.041673        2926.248369   84.037503         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History  total_Income   IncomeLog  LoanAmountLog
# count      614.000000    614.000000  614.000000     614.000000
# mean         0.855049   7024.705081    8.669414       4.861965
# std          0.352339   6458.663872    0.545102       0.496550
# min          0.000000   1442.000000    7.273786       2.197225
# ...

# %%
max_thresold = df['IncomeLog'].quantile(0.99)
max_thresold
# Out:
# 10.530669145261063

# %%
df[df['IncomeLog']>max_thresold]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 155  LP001536    Male     Yes         3+  Graduate            No
# 171  LP001585     NaN     Yes         3+  Graduate            No
# 185  LP001640    Male     Yes          0  Graduate           Yes
# 333  LP002101    Male     Yes          0  Graduate           NaN
# 409  LP002317    Male     Yes         3+  Graduate            No
# 443  LP002422    Male      No          1  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 155            39999                0.0       600.0             180.0
# 171            51763                0.0       700.0             300.0
# 185            39147             4750.0       120.0             360.0
# 333            63337                0.0       490.0             180.0
# 409            81000                0.0       360.0             360.0
# ...

# %%
min_thresold = df['IncomeLog'].quantile(0.01)
min_thresold
# Out:
# 7.669257532935698

# %%
df[df['IncomeLog']<min_thresold]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 28   LP001086    Male      No          0  Not Graduate            No
# 216  LP001722    Male     Yes          0      Graduate            No
# 305  LP001990    Male      No          0  Not Graduate            No
# 338  LP002113  Female      No         3+  Not Graduate            No
# 403  LP002300  Female      No          0  Not Graduate            No
# 541  LP002743  Female      No          0      Graduate            No
# 583  LP002898    Male     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 28              1442                0.0        35.0             360.0
# 216              150             1800.0       135.0             360.0
# 305             2000                0.0       146.0             360.0
# 338             1830                0.0       146.0             360.0
# ...

# %%
max_thresold = df['LoanAmount'].quantile(0.99)
max_thresold
# Out:
# 495.87

# %%
df[df['LoanAmount']>max_thresold]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 130  LP001469    Male      No          0  Graduate           Yes
# 155  LP001536    Male     Yes         3+  Graduate            No
# 171  LP001585     NaN     Yes         3+  Graduate            No
# 369  LP002191    Male     Yes          0  Graduate            No
# 487  LP002547    Male     Yes          1  Graduate            No
# 561  LP002813  Female     Yes          1  Graduate           Yes
# 604  LP002959  Female     Yes          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 130            20166                0.0       650.0             480.0
# 155            39999                0.0       600.0             180.0
# 171            51763                0.0       700.0             300.0
# 369            19730             5266.0       570.0             360.0
# 487            18333                0.0       500.0             360.0
# ...

# %%
min_thresold = df['LoanAmount'].quantile(0.01)
min_thresold
# Out:
# 30.65

# %%
df[df['LoanAmount']<min_thresold]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 14   LP001030    Male     Yes          2      Graduate            No
# 94   LP001325    Male      No          0  Not Graduate            No
# 133  LP001482    Male     Yes          0      Graduate           Yes
# 147  LP001518    Male     Yes          1      Graduate            No
# 270  LP001888  Female      No          0      Graduate            No
# 555  LP002792    Male     Yes          1      Graduate            No
# 568  LP002840  Female      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 14              1299             1086.0        17.0             120.0
# 94              3620                0.0        25.0             120.0
# 133             3459                0.0        25.0             120.0
# 147             1538             1425.0        30.0             360.0
# ...

# %%
df2 = df[(df.LoanAmount<max_thresold)&(df.LoanAmount>min_thresold)]
df2.shape
# Out:
# (600, 16)

# %%
df.shape
# Out:
# (614, 16)

# %%
df2.isna().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# total_Income          0
# IncomeLog             0
# LoanAmountLog         0
# dtype: int64

# %%
df2.dropna()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df2.isna().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# total_Income          0
# IncomeLog             0
# LoanAmountLog         0
# dtype: int64

# %%
df2.dropna()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
max_thresold = df['IncomeLog'].quantile(0.99)
max_thresold
# Out:
# 10.530669145261063

# %%
df[df['IncomeLog']>max_thresold]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 155  LP001536    Male     Yes         3+  Graduate            No
# 171  LP001585     NaN     Yes         3+  Graduate            No
# 185  LP001640    Male     Yes          0  Graduate           Yes
# 333  LP002101    Male     Yes          0  Graduate           NaN
# 409  LP002317    Male     Yes         3+  Graduate            No
# 443  LP002422    Male      No          1  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 155            39999                0.0       600.0             180.0
# 171            51763                0.0       700.0             300.0
# 185            39147             4750.0       120.0             360.0
# 333            63337                0.0       490.0             180.0
# 409            81000                0.0       360.0             360.0
# ...

# %%
min_thresold = df['IncomeLog'].quantile(0.01)
min_thresold
# Out:
# 7.669257532935698

# %%
df[df['IncomeLog']<min_thresold]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 28   LP001086    Male      No          0  Not Graduate            No
# 216  LP001722    Male     Yes          0      Graduate            No
# 305  LP001990    Male      No          0  Not Graduate            No
# 338  LP002113  Female      No         3+  Not Graduate            No
# 403  LP002300  Female      No          0  Not Graduate            No
# 541  LP002743  Female      No          0      Graduate            No
# 583  LP002898    Male     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 28              1442                0.0        35.0             360.0
# 216              150             1800.0       135.0             360.0
# 305             2000                0.0       146.0             360.0
# 338             1830                0.0       146.0             360.0
# ...

# %%
df2 = df[(df.IncomeLog<max_thresold)&(df.IncomeLog>min_thresold)]

# %%
df2.shape
# Out:
# (600, 16)

# %%
min_thresold
# Out:
# 7.669257532935698

# %%
df2.isna().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               3
# Dependents           15
# Education             0
# Self_Employed        30
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# total_Income          0
# IncomeLog             0
# LoanAmountLog         0
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (543, 16)

# %%
min_thresold
# Out:
# 7.669257532935698

# %%
df2 = df[(df.IncomeLog<max_thresold)&(df.IncomeLog>min_thresold)]
df2.shape
# Out:
# (600, 16)

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (543, 16)

# %%
df2[df2['IncomeLog']<min_thresold]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status, total_Income, IncomeLog, LoanAmountLog]
# Index: []

# %%
df2[df2['IncomeLog']>max_thresold]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status, total_Income, IncomeLog, LoanAmountLog]
# Index: []

# %%
df2[df2['LoanAmount']<30.65]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 14   LP001030    Male     Yes          2      Graduate            No
# 94   LP001325    Male      No          0  Not Graduate            No
# 133  LP001482    Male     Yes          0      Graduate           Yes
# 147  LP001518    Male     Yes          1      Graduate            No
# 270  LP001888  Female      No          0      Graduate            No
# 555  LP002792    Male     Yes          1      Graduate            No
# 568  LP002840  Female      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 14              1299             1086.0        17.0             120.0
# 94              3620                0.0        25.0             120.0
# 133             3459                0.0        25.0             120.0
# 147             1538             1425.0        30.0             360.0
# ...

# %%
df2[(df2.LoanAmount>495.87)]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 130  LP001469    Male      No          0  Graduate           Yes
# 369  LP002191    Male     Yes          0  Graduate            No
# 487  LP002547    Male     Yes          1  Graduate            No
# 561  LP002813  Female     Yes          1  Graduate           Yes
# 604  LP002959  Female     Yes          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 130            20166                0.0       650.0             480.0
# 369            19730             5266.0       570.0             360.0
# 487            18333                0.0       500.0             360.0
# 561            19484                0.0       600.0             360.0
# 604            12000                0.0       496.0             360.0
#
#      Credit_History Property_Area Loan_Status  total_Income  IncomeLog  \
# 130             1.0         Urban           Y       20166.0   9.911753
# ...

# %%
df2.shape
# Out:
# (543, 16)

# %%
df2.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# total_Income         0
# IncomeLog            0
# LoanAmountLog        0
# dtype: int64

# %%
df2 = df2[(df2.LoanAmount<495.87)&(df2.LoanAmount>30.65)]

# %%
df2.shape
# Out:
# (531, 16)

# %%
df2[(df2.LoanAmount>495.87)]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status, total_Income, IncomeLog, LoanAmountLog]
# Index: []

# %%
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbl_encode = LabelEncoder()
df2['Loan_Status'] = lbl_encode.fit_transform(df2['Loan_Status'])

# %%
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df2['Gender'] = lbl_encode.fit_transform(df2['Gender'])

# %%
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002       1      No          0      Graduate            No
# 1    LP001003       1     Yes          1      Graduate            No
# 2    LP001005       1     Yes          0      Graduate           Yes
# 3    LP001006       1     Yes          0  Not Graduate            No
# 4    LP001008       1      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978       0      No          0      Graduate            No
# 610  LP002979       1     Yes         3+      Graduate            No
# 611  LP002983       1     Yes          1      Graduate            No
# 612  LP002984       1     Yes          2      Graduate            No
# 613  LP002990       0      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df2['Married'] = lbl_encode.fit_transform(df2['Married'])
df2['Educatiom'] = lbl_encode.fit_transform(df2['Education'])
df2['Self_Employed'] = lbl_encode.fit_transform(df2['Self_Employed'])
df2['Property_Area'] = lbl_encode.fit_transform(df2['Property_Area'])

# %%
df2
# Out:
#       Loan_ID  Gender  Married Dependents     Education  Self_Employed  \
# 0    LP001002       1        0          0      Graduate              0
# 1    LP001003       1        1          1      Graduate              0
# 2    LP001005       1        1          0      Graduate              1
# 3    LP001006       1        1          0  Not Graduate              0
# 4    LP001008       1        0          0      Graduate              0
# ..        ...     ...      ...        ...           ...            ...
# 609  LP002978       0        0          0      Graduate              0
# 610  LP002979       1        1         3+      Graduate              0
# 611  LP002983       1        1          1      Graduate              0
# 612  LP002984       1        1          2      Graduate              0
# 613  LP002990       0        0          0      Graduate              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df2['Education'] = lbl_encode.fit_transform(df2['Education'])

# %%
pd.crosstab(df2.Loan_Amount_Term,df2.Loan_Status).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term'>

# %%
df2
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          0              0
# 610  LP002979       1        1         3+          0              0
# 611  LP002983       1        1          1          0              0
# 612  LP002984       1        1          2          0              0
# 613  LP002990       0        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       146.0             360.0
# ...

# %%
df2['Dependents'] = lbl_encode.fit_transform(df2['Dependents'])
df2
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              1
# 3    LP001006       1        1           0          1              0
# 4    LP001008       1        0           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          0              0
# 610  LP002979       1        1           3          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           2          0              0
# 613  LP002990       0        0           0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
cols = ['Loan_ID','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','total_Income','Educatiom']
df2 = df2.drop(columns=cols, axis=1)
df2
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0             1.0
# 1         1        1           1          0              0             1.0
# 2         1        1           0          0              1             1.0
# 3         1        1           0          1              0             1.0
# 4         1        0           0          0              0             1.0
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          0              0             1.0
# 610       1        1           3          0              0             1.0
# 611       1        1           1          0              0             1.0
# 612       1        1           2          0              0             1.0
# 613       0        0           0          0              1             0.0
#
#      Property_Area  Loan_Status  IncomeLog  LoanAmountLog
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import cross_val_score

# %%
X = df2.drop(columns=['Loan_Status'], axis=1)
y = df2['Loan_Status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','poly']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    'Decision_Tree' :{
        'model': DecisionTreeClassifier(),
        'params':{
        'min_samples_split': [2,5,10]
        }
    },
    'GaussianNB' : {
        'model': GaussianNB(),
        'params':{
            
        }
    },
    'MultinomialNB':{
        'model': MultinomialNB(),
        'params':{
            'alpha': [1.0,2.0,5.0,10.0] 
        }
    }
    
    
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X, y)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df3 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df3
# Out:
#                  model  best_score                best_params
# 0                  svm    0.815412  {'C': 1, 'kernel': 'rbf'}
# 1        random_forest    0.745794        {'n_estimators': 5}
# 2  logistic_regression    0.815412                   {'C': 1}
# 3        Decision_Tree    0.724987  {'min_samples_split': 10}
# 4           GaussianNB    0.807865                         {}
# 5        MultinomialNB    0.698677            {'alpha': 10.0}

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
model.score(X_test,y_test)
# Out:
# 0.8411214953271028

# %%
import pickle
with open('Loan_Prediction_model.pickle','wb') as f:
    pickle.dump(model,f)
